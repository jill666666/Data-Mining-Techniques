# %% [markdown]
# # Problem 4

# %% [markdown]
# ## Section A

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
from sklearn.preprocessing import normalize
from sklearn.mixture import GaussianMixture

# %%
(X_train, y_train) , (X_test, y_test)= fashion_mnist.load_data()

X_train = normalize(X_train.reshape(60000, 784))
X_test = normalize(X_test.reshape(10000, 784))

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
list_aic_metrics = []
num_components = range(1, 10)

for k in num_components:
    gmm = GaussianMixture(n_components=k, covariance_type='diag').fit(X_test)
    list_aic_metrics.append(gmm.aic(X_test))

# %%
plt.title('AIC by number of components')
plt.xlabel('number of components')
plt.ylabel('AIC')
plt.plot(num_components, list_aic_metrics)

# %% [markdown]
# ## Section B

# %%
def parse_data_file(filename, train_set=[]):
    with open(filename) as f:
        line = f.readline()
        while line:
            elements = [float(v) for v in line.split(',')]
            train_set.append(elements)
            line = f.readline()
    return np.array(train_set)

# %%
train_set = parse_data_file('spambase.data')
train_set.shape
# Out:
# (4601, 58)

# %%
list_aic_metrics = []
num_components = range(1, 10)

for k in num_components:
    gmm = GaussianMixture(n_components=k, covariance_type='diag', random_state=0).fit(train_set)
    list_aic_metrics.append(gmm.aic(train_set))

# %%
plt.title('AIC by number of components')
plt.xlabel('number of components')
plt.ylabel('AIC')
plt.plot(num_components, list_aic_metrics)
